# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\uri.itai\Downloads\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass  \
# count    891.000000  891.000000  891.000000
# unique          NaN         NaN         NaN
# top             NaN         NaN         NaN
# freq            NaN         NaN         NaN
# mean     446.000000    0.383838    2.308642
# std      257.353842    0.486592    0.836071
# min        1.000000    0.000000    1.000000
# 25%      223.500000    0.000000    2.000000
# 50%      446.000000    0.000000    3.000000
# 75%      668.500000    1.000000    3.000000
# max      891.000000    1.000000    3.000000
#
#                                           Name   Sex         Age       SibSp  \
# count                                      891   891  714.000000  891.000000
# unique                                     891     2         NaN         NaN
# top     Chibnall, Mrs. (Edith Martha Bowerman)  male         NaN         NaN
# freq                                         1   577         NaN         NaN
# ...

# %%
df[df.Sex== 'female'].Survived.mean()
# Out:
# 0.7420382165605095

# %%
df.Sex.value_counts(normalize = True)
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
df['onehot_set'] = df.Sex == 'male'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  onehot_set   891 non-null    bool
# dtypes: bool(1), float64(2), int64(5), object(5)
# memory usage: 84.5+ KB

# %%
sns.pairplot(df[df.Sex =='female'],hue = 'Survived')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
# onehot_set      0.042939 -0.543351  0.131900  0.093254 -0.114631 -0.245489
#
#                  Fare  onehot_set
# PassengerId  0.012658    0.042939
# Survived     0.257307   -0.543351
# Pclass      -0.549500    0.131900
# Age          0.096067    0.093254
# SibSp        0.159651   -0.114631
# Parch        0.216225   -0.245489
# Fare         1.000000   -0.182333
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.groupby(['Pclass','Sex','SibSp']).agg(['mean','count'])['Survived']#.plot(kind = 'bar')
# Out:
#                          mean  count
# Pclass Sex    SibSp
# 1      female 0      0.979592     49
#               1      0.950000     40
#               2      1.000000      3
#               3      1.000000      2
#        male   0      0.329545     88
#               1      0.483871     31
#               2      0.500000      2
#               3      0.000000      1
# 2      female 0      0.931818     44
#               1      0.892857     28
#               2      1.000000      3
#               3      1.000000      1
#        male   0      0.118421     76
#               1      0.259259     27
#               2      0.200000      5
# 3      female 0      0.592593     81
#               1      0.447368     38
#               2      0.571429      7
#               3      0.125000      8
#               4      0.333333      6
#               5      0.000000      1
#               8      0.000000      3
#        male   0      0.129630    270
#               1      0.222222     45
# ...

# %%
df3 = df.drop(df[df['Age'].isna()].index)

# %%
df3[['Cabin','Sex']].describe()
# Out:
#           Cabin   Sex
# count       185   714
# unique      134     2
# top     B96 B98  male
# freq          4   453

# %%
df3['Sex'].value_counts()
# Out:
# male      453
# female    261
# Name: Sex, dtype: int64

# %%
df3.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000  0.029340 -0.035349  0.036847 -0.082398 -0.011617
# Survived        0.029340  1.000000 -0.359653 -0.077221 -0.017358  0.093317
# Pclass         -0.035349 -0.359653  1.000000 -0.369226  0.067247  0.025683
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.082398 -0.017358  0.067247 -0.308247  1.000000  0.383820
# Parch          -0.011617  0.093317  0.025683 -0.189119  0.383820  1.000000
# Fare            0.009592  0.268189 -0.554182  0.096067  0.138329  0.205119
#
#                  Fare
# PassengerId  0.009592
# Survived     0.268189
# Pclass      -0.554182
# Age          0.096067
# SibSp        0.138329
# Parch        0.205119
# Fare         1.000000

# %%
#df3.groupby(['Sex','Survived']).mean()
df.groupby(['Sex']).mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test.groupby(['Pclass','Sex']).median()
# Out:
#                PassengerId   Age  SibSp  Parch      Fare
# Pclass Sex
# 1      female       1088.0  41.0    0.0    0.0  79.02500
#        male         1094.0  42.0    0.0    0.0  51.86250
# 2      female       1122.0  24.0    0.0    0.0  26.00000
#        male         1122.0  28.0    0.0    0.0  13.00000
# 3      female       1070.5  22.0    0.0    0.0   8.08125
#        male         1102.5  24.0    0.0    0.0   7.89580

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df[df['Age'].isna()]['Sex'].value_counts()
# Out:
# male      124
# female     53
# Name: Sex, dtype: int64

# %%
df.plot.scatter(x="Pclass", y="Fare", alpha=0.15)
plt.title('scart of pclass and fare')
plt.show()

# %%
df.groupby(['Sex','Pclass']).agg(['mean','count'])
# Out:
#               PassengerId        Survived              Age           SibSp  \
#                      mean count      mean count       mean count      mean
# Sex    Pclass
# female 1       469.212766    94  0.968085    94  34.611765    85  0.553191
#        2       443.105263    76  0.921053    76  28.722973    74  0.486842
#        3       399.729167   144  0.500000   144  21.750000   102  0.895833
# male   1       455.729508   122  0.368852   122  41.281386   101  0.311475
#        2       447.962963   108  0.157407   108  30.740707    99  0.342593
#        3       455.515850   347  0.135447   347  26.507589   253  0.498559
#
#                         Parch              Fare       onehot_set        \
#               count      mean count        mean count       mean count
# Sex    Pclass
# female 1         94  0.457447    94  106.125798    94      False    94
#        2         76  0.605263    76   21.970121    76      False    76
# ...

# %%
df[['Age','Survived']].groupby('Age').mean()
# Out:
#        Survived
# Age
# 0.42        1.0
# 0.67        1.0
# 0.75        1.0
# 0.83        1.0
# 0.92        1.0
# ...         ...
# 70.00       0.0
# 70.50       0.0
# 71.00       0.0
# 74.00       0.0
# 80.00       1.0
#
# [88 rows x 1 columns]

# %%
df['age_decad'] = df.Age.apply(lambda x : 5*(x//5) )
df[['age_decad','Survived']].groupby('age_decad').agg(['mean','count'])
# Out:
#            Survived
#                mean count
# age_decad
# 0.0        0.675000    40
# 5.0        0.500000    22
# 10.0       0.437500    16
# 15.0       0.395349    86
# 20.0       0.342105   114
# 25.0       0.358491   106
# 30.0       0.421053    95
# 35.0       0.458333    72
# 40.0       0.375000    48
# 45.0       0.390244    41
# 50.0       0.437500    32
# 55.0       0.375000    16
# 60.0       0.400000    15
# 65.0       0.000000     4
# 70.0       0.000000     6
# 80.0       1.000000     1

# %%
df[['Age','Survived']].groupby('Survived').hist()
# Out:
# Survived
# 0    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 1    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# dtype: object

# %%
# removed rows where age was nan (many nan entries in age)
df3 = df.drop(df[df['Age'].isna()].index)
# fare correlated inversely to Pclass (corr)
df3.corr()
# survivors tend to be rich (corr(Pclass,Survived)=0.35)
# 75% of women survived vs. 20% of men
df3.groupby(['Sex']).mean()
# returned rows where age was nan
# 74% of women survived vs. 18% of men
df.groupby(['Sex']).mean()
# larger percentage of survivors were children
df[['Age','Survived']].groupby('Survived').hist()

# %%
df.Name.tolist()
# Out:
# ['Braund, Mr. Owen Harris',
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#  'Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry',
#  'Moran, Mr. James',
#  'McCarthy, Mr. Timothy J',
#  'Palsson, Master. Gosta Leonard',
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'Nasser, Mrs. Nicholas (Adele Achem)',
#  'Sandstrom, Miss. Marguerite Rut',
#  'Bonnell, Miss. Elizabeth',
#  'Saundercock, Mr. William Henry',
#  'Andersson, Mr. Anders Johan',
#  'Vestrom, Miss. Hulda Amanda Adolfina',
#  'Hewlett, Mrs. (Mary D Kingcome) ',
#  'Rice, Master. Eugene',
#  'Williams, Mr. Charles Eugene',
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Masselmani, Mrs. Fatima',
#  'Fynney, Mr. Joseph J',
#  'Beesley, Mr. Lawrence',
#  'McGowan, Miss. Anna "Annie"',
#  'Sloper, Mr. William Thompson',
#  'Palsson, Miss. Torborg Danira',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
# ...

# %%
df[df.Name == 'Greenfield, Mr. William Bertram']
# Out:
#     PassengerId  Survived  Pclass                             Name   Sex  \
# 97           98         1       1  Greenfield, Mr. William Bertram  male
#
#      Age  SibSp  Parch    Ticket     Fare    Cabin Embarked  onehot_set  \
# 97  23.0      0      1  PC 17759  63.3583  D10 D12        C        True
#
#     age_decad
# 97       20.0

# %%
df[(df.Age-df.Age.mean())/df.Age.std() > 3]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked  onehot_set  \
# 630  male  80.0      0      0   27042  30.000   A23        S        True
# 851  male  74.0      0      0  347060   7.775   NaN        S        True
#
#      age_decad
# 630       80.0
# 851       70.0

# %%
df[(df.Fare-df.Fare.mean())/df.Fare.std() > 3]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 377          378         0       1
# 380          381         1       1
# 438          439         0       1
# 527          528         0       1
# 557          558         0       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ...

# %%
df.Fare.hist()

# %%
df[df.Fare > 200].Survived.mean()
# Out:
# 0.7
