# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import pandas_profiling

# %%
df_titanic = pd.read_csv('train.csv')
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df_titanic, title="Pandas Profiling Report")

# %%
profile.to_file("titanic_raw_data.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 37.05it/s]

# %%
df_titanic.shape
# Out:
# (891, 12)

# %%
df_titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass  \
# count    891.000000  891.000000  891.000000
# unique          NaN         NaN         NaN
# top             NaN         NaN         NaN
# freq            NaN         NaN         NaN
# mean     446.000000    0.383838    2.308642
# std      257.353842    0.486592    0.836071
# min        1.000000    0.000000    1.000000
# 25%      223.500000    0.000000    2.000000
# 50%      446.000000    0.000000    3.000000
# 75%      668.500000    1.000000    3.000000
# max      891.000000    1.000000    3.000000
#
#                                                      Name   Sex         Age  \
# count                                                 891   891  714.000000
# unique                                                891     2         NaN
# top     Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  male         NaN
# freq                                                    1   577         NaN
# ...

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.pairplot(df_titanic[df_titanic.Sex=='femaile'], hue='Survived')

# %%
df_titanic['one_hot_set']=df_titanic.Sex=='male'

# %%
df_titanic.groupby(['Pclass','Sex']).mean()['Survived'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Pclass,Sex'>

# %%
df_titanic.groupby(['Pclass','Sex']).agg(['mean','count'])['Survived']
# Out:
#                    mean  count
# Pclass Sex
# 1      female  0.968085     94
#        male    0.368852    122
# 2      female  0.921053     76
#        male    0.157407    108
# 3      female  0.500000    144
#        male    0.135447    347

# %%
df_titanic['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
corr = df_titanic.corr()
sns.heatmap(corr);

# %%
df_titanic.skew()
# Out:
# PassengerId    0.000000
# Survived       0.478523
# Pclass        -0.630548
# Age            0.389108
# SibSp          3.695352
# Parch          2.749117
# Fare           4.787317
# dtype: float64

# %%
df_titanic.kurtosis()
# Out:
# PassengerId    -1.200000
# Survived       -1.775005
# Pclass         -1.280015
# Age             0.178274
# SibSp          17.880420
# Parch           9.778125
# Fare           33.398141
# dtype: float64

# %%
df_titanic.Survived.value_counts(normalize=True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
df_titanic.Survived.value_counts().plot(kind='bar');
# Out:
# <AxesSubplot:>

# %%
sns.countplot( x='Sex', hue='Survived', data=df_titanic)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
df_titanic.Sex.value_counts(normalize=True).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.boxplot(x=df_titanic.Survived,  y=df_titanic.Age)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
df_titanic.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df_titanic.groupby('Pclass').mean()
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
df_titanic[['Age','Survived']].groupby('Age').mean()
# Out:
#        Survived
# Age
# 0.42        1.0
# 0.67        1.0
# 0.75        1.0
# 0.83        1.0
# 0.92        1.0
# ...         ...
# 70.00       0.0
# 70.50       0.0
# 71.00       0.0
# 74.00       0.0
# 80.00       1.0
#
# [88 rows x 1 columns]

# %%
df_titanic['age_decade']=df_titanic.Age.apply(lambda x:x//5)
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
